# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Heading
# This is a text cell.

# %%
s = 10
t = 20
s/t
# Out:
# 0.5

# %%
import numpy
import pandas
import matplotlib.pylab as plt

# %%
plt.plot([6,12,15,5,9,10], [3,8,19,4,15,20])

# %%
plt.scatter([6,12,15,5,9,10], [3,8,19,4,15,20])
